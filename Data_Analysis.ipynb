# %%
pip install pandas
# Out:
# ...
#
# ...

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import seaborn  as sns
import matplotlib.pyplot as plt

# %%
kashti = sns.load_dataset("titanic")
kashti
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
kashti.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
kashti.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
kashti.survived.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='survived'>

# %%
sns.countplot(x="survived",data=kashti)
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
plt.scatter(data=kashti,x="age",y="fare")

# %%
sns.scatterplot(x="age",data=kashti,y="fare",hue="pclass")
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.barplot(x="sex",data=kashti,y="fare",hue="pclass")
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
sns.pairplot(kashti)

# %%
kashti.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
kashti.hist(bins=10, figsize=(9, 7), grid=False)
# Out:
# array([[<Axes: title={'center': 'survived'}>,
#         <Axes: title={'center': 'pclass'}>],
#        [<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'sibsp'}>],
#        [<Axes: title={'center': 'parch'}>,
#         <Axes: title={'center': 'fare'}>]], dtype=object)

# %%
sns.boxplot(data=kashti,x="sex",y="fare",hue="who")
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
kashti.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
sns.boxenplot(data=kashti,x="sex",y="fare",hue="who")
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
s = sns.FacetGrid(kashti, hue="survived", col="pclass", margin_titles=True,
                  palette={1: "seagreen", 0: "gray"})
g = s.map(plt.scatter, "fare", "age", edgecolor="w")

# %%
sns.stripplot(data=kashti, x="sex", y="fare", hue="class")
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
sns.violinplot(data=kashti, x="class", y="fare", hue="sex")
plt.show()

# %%
dates = pd.date_range("20130101", periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.149039  0.079963 -0.888603 -0.013899
# 2013-01-02 -0.480342  0.033053  1.603246 -0.912825
# 2013-01-03  0.715032 -0.921723  0.243425 -0.270635
# 2013-01-04  1.569174 -0.380942  1.527366 -0.586261
# 2013-01-05 -0.994697  1.268256 -0.698853  0.398045
# 2013-01-06  0.352660 -0.575821 -0.838861 -1.706028

# %%
df.iloc[:,0:1]
# Out:
#                    A
# 2013-01-01  0.149039
# 2013-01-02 -0.480342
# 2013-01-03  0.715032
# 2013-01-04  1.569174
# 2013-01-05 -0.994697
# 2013-01-06  0.352660

# %%
df.loc[:,["A","B"]]
# Out:
#                    A         B
# 2013-01-01  0.149039  0.079963
# 2013-01-02 -0.480342  0.033053
# 2013-01-03  0.715032 -0.921723
# 2013-01-04  1.569174 -0.380942
# 2013-01-05 -0.994697  1.268256
# 2013-01-06  0.352660 -0.575821

# %%
df[0:2]
# Out:
#                    A         B         C         D
# 2013-01-01  0.149039  0.079963 -0.888603 -0.013899
# 2013-01-02 -0.480342  0.033053  1.603246 -0.912825

# %%
import seaborn as sns

# %%
kashti = sns.load_dataset("titanic")
kashti
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
kashti.sample(100)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 788         1       3    male   1.0      1      2   20.5750        S   Third
# 647         1       1    male  56.0      0      0   35.5000        C   First
# 505         0       1    male  18.0      1      0  108.9000        C   First
# 472         1       2  female  33.0      1      2   27.7500        S  Second
# 666         0       2    male  25.0      0      0   13.0000        S  Second
# ..        ...     ...     ...   ...    ...    ...       ...      ...     ...
# 181         0       2    male   NaN      0      0   15.0500        C  Second
# 66          1       2  female  29.0      0      0   10.5000        S  Second
# 880         1       2  female  25.0      0      1   26.0000        S  Second
# 413         0       2    male   NaN      0      0    0.0000        S  Second
# 608         1       2  female  22.0      1      2   41.5792        C  Second
#
# ...

# %%
kashti[kashti['age']>60]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 33          0       2    male  66.0      0      0   10.5000        S  Second
# 54          0       1    male  65.0      0      1   61.9792        C   First
# 96          0       1    male  71.0      0      0   34.6542        C   First
# 116         0       3    male  70.5      0      0    7.7500        Q   Third
# 170         0       1    male  61.0      0      0   33.5000        S   First
# 252         0       1    male  62.0      0      0   26.5500        S   First
# 275         1       1  female  63.0      1      0   77.9583        S   First
# 280         0       3    male  65.0      0      0    7.7500        Q   Third
# 326         0       3    male  61.0      0      0    6.2375        S   Third
# 438         0       1    male  64.0      1      4  263.0000        S   First
# 456         0       1    male  65.0      0      0   26.5500        S   First
# ...

# %%
df.iat[1, 1]
# Out:
# 0.033052685283660864

# %%
 df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2013-01-04  1.569174 -0.380942
# 2013-01-05 -0.994697  1.268256

# %%
df.iloc[[1, 2, 4], [0, 2]]
# Out:
#                    A         C
# 2013-01-02 -0.480342  1.603246
# 2013-01-03  0.715032  0.243425
# 2013-01-05 -0.994697 -0.698853

# %%
df.iat[1, 1]
# Out:
# 0.033052685283660864

# %%
df2 = df.copy()
df2
# Out:
#                    A         B         C         D
# 2013-01-01  0.149039  0.079963 -0.888603 -0.013899
# 2013-01-02 -0.480342  0.033053  1.603246 -0.912825
# 2013-01-03  0.715032 -0.921723  0.243425 -0.270635
# 2013-01-04  1.569174 -0.380942  1.527366 -0.586261
# 2013-01-05 -0.994697  1.268256 -0.698853  0.398045
# 2013-01-06  0.352660 -0.575821 -0.838861 -1.706028

# %%
df2 = df.copy()
df2["E"] = ["one", "one", "two", "three", "four", "three"]
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01  0.149039  0.079963 -0.888603 -0.013899    one
# 2013-01-02 -0.480342  0.033053  1.603246 -0.912825    one
# 2013-01-03  0.715032 -0.921723  0.243425 -0.270635    two
# 2013-01-04  1.569174 -0.380942  1.527366 -0.586261  three
# 2013-01-05 -0.994697  1.268256 -0.698853  0.398045   four
# 2013-01-06  0.352660 -0.575821 -0.838861 -1.706028  three

# %%
df.at[dates[0], "A"] = 0
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.000000  0.079963 -0.888603 -0.013899
# 2013-01-02 -0.480342  0.033053  1.603246 -0.912825
# 2013-01-03  0.715032 -0.921723  0.243425 -0.270635
# 2013-01-04  1.569174 -0.380942  1.527366 -0.586261
# 2013-01-05 -0.994697  1.268256 -0.698853  0.398045
# 2013-01-06  0.352660 -0.575821 -0.838861 -1.706028

# %%
df.loc[:, "D"] = np.array([5] * len(df))                           
df
# Out:
#                    A         B         C    D
# 2013-01-01  0.000000  0.079963 -0.888603  5.0
# 2013-01-02 -0.480342  0.033053  1.603246  5.0
# 2013-01-03  0.715032 -0.921723  0.243425  5.0
# 2013-01-04  1.569174 -0.380942  1.527366  5.0
# 2013-01-05 -0.994697  1.268256 -0.698853  5.0
# 2013-01-06  0.352660 -0.575821 -0.838861  5.0

# %%
df
# Out:
#                    A         B         C    D
# 2013-01-01  0.000000  0.079963 -0.888603  5.0
# 2013-01-02 -0.480342  0.033053  1.603246  5.0
# 2013-01-03  0.715032 -0.921723  0.243425  5.0
# 2013-01-04  1.569174 -0.380942  1.527366  5.0
# 2013-01-05 -0.994697  1.268256 -0.698853  5.0
# 2013-01-06  0.352660 -0.575821 -0.838861  5.0

# %%
df2 = df.copy()

df2[df2 > 0] = -df2

df
# Out:
#                    A         B         C    D
# 2013-01-01  0.000000  0.079963 -0.888603  5.0
# 2013-01-02 -0.480342  0.033053  1.603246  5.0
# 2013-01-03  0.715032 -0.921723  0.243425  5.0
# 2013-01-04  1.569174 -0.380942  1.527366  5.0
# 2013-01-05 -0.994697  1.268256 -0.698853  5.0
# 2013-01-06  0.352660 -0.575821 -0.838861  5.0

# %%
df2 = df.copy()
df2[df2 > 0] = -df2
df2
# Out:
#                    A         B         C    D
# 2013-01-01  0.000000 -0.079963 -0.888603 -5.0
# 2013-01-02 -0.480342 -0.033053 -1.603246 -5.0
# 2013-01-03 -0.715032 -0.921723 -0.243425 -5.0
# 2013-01-04 -1.569174 -0.380942 -1.527366 -5.0
# 2013-01-05 -0.994697 -1.268256 -0.698853 -5.0
# 2013-01-06 -0.352660 -0.575821 -0.838861 -5.0

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ["E"])
df1.loc[dates[0] : dates[1], "E"] = 1

df1
# Out:
#                    A         B         C    D    E
# 2013-01-01  0.000000  0.079963 -0.888603  5.0  1.0
# 2013-01-02 -0.480342  0.033053  1.603246  5.0  1.0
# 2013-01-03  0.715032 -0.921723  0.243425  5.0  NaN
# 2013-01-04  1.569174 -0.380942  1.527366  5.0  NaN

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns)+["E"])
df1.loc[dates[0] : dates[1], "E"] = 1

df1
# Out:
#                    A         B         C    D    E
# 2013-01-01  0.000000  0.079963 -0.888603  5.0  1.0
# 2013-01-02 -0.480342  0.033053  1.603246  5.0  1.0
# 2013-01-03  0.715032 -0.921723  0.243425  5.0  NaN
# 2013-01-04  1.569174 -0.380942  1.527366  5.0  NaN

# %%
df1.dropna()
# Out:
#                    A         B         C    D    E
# 2013-01-01  0.000000  0.079963 -0.888603  5.0  1.0
# 2013-01-02 -0.480342  0.033053  1.603246  5.0  1.0

# %%
df1.fillna(value=2)
df1
# Out:
#                    A         B         C    D    E
# 2013-01-01  0.000000  0.079963 -0.888603  5.0  1.0
# 2013-01-02 -0.480342  0.033053  1.603246  5.0  1.0
# 2013-01-03  0.715032 -0.921723  0.243425  5.0  NaN
# 2013-01-04  1.569174 -0.380942  1.527366  5.0  NaN

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      E
# 2013-01-01  False  False  False  False  False
# 2013-01-02  False  False  False  False  False
# 2013-01-03  False  False  False  False   True
# 2013-01-04  False  False  False  False   True

# %%
df.mean()
# Out:
# A    0.193638
# B   -0.082869
# C    0.157954
# D    5.000000
# dtype: float64

# %%
df.mean(axis=1)
df
# Out:
#                    A         B         C    D
# 2013-01-01  0.000000  0.079963 -0.888603  5.0
# 2013-01-02 -0.480342  0.033053  1.603246  5.0
# 2013-01-03  0.715032 -0.921723  0.243425  5.0
# 2013-01-04  1.569174 -0.380942  1.527366  5.0
# 2013-01-05 -0.994697  1.268256 -0.698853  5.0
# 2013-01-06  0.352660 -0.575821 -0.838861  5.0

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8], index=dates).shift(2)
s
df.groupby("A")[["C", "D"]].sum()
df
# Out:
#                    A         B         C    D
# 2013-01-01  0.000000  0.079963 -0.888603  5.0
# 2013-01-02 -0.480342  0.033053  1.603246  5.0
# 2013-01-03  0.715032 -0.921723  0.243425  5.0
# 2013-01-04  1.569174 -0.380942  1.527366  5.0
# 2013-01-05 -0.994697  1.268256 -0.698853  5.0
# 2013-01-06  0.352660 -0.575821 -0.838861  5.0

# %%
arrays = [
   ["bar", "bar", "baz", "baz", "foo", "foo", "qux", "qux"],
   ["one", "two", "one", "two", "one", "two", "one", "two"],
]

# %%
index = pd.MultiIndex.from_arrays(arrays, names=["first", "second"])
index
# Out:
# MultiIndex([('bar', 'one'),
#             ('bar', 'two'),
#             ('baz', 'one'),
#             ('baz', 'two'),
#             ('foo', 'one'),
#             ('foo', 'two'),
#             ('qux', 'one'),
#             ('qux', 'two')],
#            names=['first', 'second'])

# %%
import pandas as pd

# Sample arrays for MultiIndex
arrays = [['A', 'A', 'B', 'B'], [1, 2, 1, 2]]

# Creating a MultiIndex with specified names
index = pd.MultiIndex.from_arrays(arrays, names=["first", "second"])

# Displaying the MultiIndex
print(index)
# Out:
# MultiIndex([('A', 1),
#             ('A', 2),
#             ('B', 1),
#             ('B', 2)],
#            names=['first', 'second'])

# %%
# Stacking with future compatibility
stacked = df.stack(future_stack=True)
stacked
# Out:
# 2013-01-01  A    0.000000
#             B    0.079963
#             C   -0.888603
#             D    5.000000
# 2013-01-02  A   -0.480342
#             B    0.033053
#             C    1.603246
#             D    5.000000
# 2013-01-03  A    0.715032
#             B   -0.921723
#             C    0.243425
#             D    5.000000
# 2013-01-04  A    1.569174
#             B   -0.380942
#             C    1.527366
#             D    5.000000
# 2013-01-05  A   -0.994697
#             B    1.268256
#             C   -0.698853
#             D    5.000000
# 2013-01-06  A    0.352660
#             B   -0.575821
#             C   -0.838861
#             D    5.000000
# dtype: float64

# %%
stacked.unstack(0)
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    0.000000   -0.480342    0.715032    1.569174   -0.994697    0.352660
# B    0.079963    0.033053   -0.921723   -0.380942    1.268256   -0.575821
# C   -0.888603    1.603246    0.243425    1.527366   -0.698853   -0.838861
# D    5.000000    5.000000    5.000000    5.000000    5.000000    5.000000

# %%
df.loc["20130102":"20130104", ["A", "B"]]
# Out:
#                    A         B
# 2013-01-02 -0.480342  0.033053
# 2013-01-03  0.715032 -0.921723
# 2013-01-04  1.569174 -0.380942

# %%
 df.loc[dates[0], "A"]
# Out:
# 0.0

# %%
df.at[dates[0], "A"]
# Out:
# 0.0

# %%
df.agg(lambda x: np.mean(x) * 5.6)
df
# Out:
#                    A         B         C    D
# 2013-01-01  0.000000  0.079963 -0.888603  5.0
# 2013-01-02 -0.480342  0.033053  1.603246  5.0
# 2013-01-03  0.715032 -0.921723  0.243425  5.0
# 2013-01-04  1.569174 -0.380942  1.527366  5.0
# 2013-01-05 -0.994697  1.268256 -0.698853  5.0
# 2013-01-06  0.352660 -0.575821 -0.838861  5.0

# %%
df.transform(lambda x: x*101.2)
# Out:
#                      A           B           C      D
# 2013-01-01    0.000000    8.092271  -89.926606  506.0
# 2013-01-02  -48.610566    3.344932  162.248539  506.0
# 2013-01-03   72.361234  -93.278319   24.634634  506.0
# 2013-01-04  158.800376  -38.551367  154.569419  506.0
# 2013-01-05 -100.663338  128.347483  -70.723879  506.0
# 2013-01-06   35.689236  -58.273117  -84.892687  506.0

# %%
s = pd.Series(np.random.randint(0,7,size=10))
s
# Out:
# 0    1
# 1    3
# 2    5
# 3    6
# 4    6
# 5    5
# 6    4
# 7    3
# 8    3
# 9    2
# dtype: int32

# %%
s = pd.Series(["A", "B", "C", "Aaba", "Baca", np.nan, "CABA", "dog", "cat"])

# %%
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
df = pd.DataFrame(np.random.randn(10, 4))
df
# Out:
#           0         1         2         3
# 0  1.175015  1.322469 -1.692536  0.357526
# 1 -1.021023  1.781037  1.193684 -1.463627
# 2 -0.568609 -0.281539  1.014631  0.197154
# 3  2.453645 -0.004983  1.176666 -0.755122
# 4 -2.017929 -0.057934 -0.848184 -0.381368
# 5 -1.542693 -0.805007  0.919762 -0.098643
# 6 -1.217098 -1.100795 -0.160036 -1.177222
# 7 -0.411526  0.736221  0.586045 -0.099311
# 8  0.576997 -1.237087  1.620517 -0.348131
# 9  0.822611 -0.400705  0.530290 -0.461586

# %%
pieces = [df[:3], df[3:7], df[7:]]
pieces
# Out:
# [          0         1         2         3
#  0  1.175015  1.322469 -1.692536  0.357526
#  1 -1.021023  1.781037  1.193684 -1.463627
#  2 -0.568609 -0.281539  1.014631  0.197154,
#            0         1         2         3
#  3  2.453645 -0.004983  1.176666 -0.755122
#  4 -2.017929 -0.057934 -0.848184 -0.381368
#  5 -1.542693 -0.805007  0.919762 -0.098643
#  6 -1.217098 -1.100795 -0.160036 -1.177222,
#            0         1         2         3
#  7 -0.411526  0.736221  0.586045 -0.099311
#  8  0.576997 -1.237087  1.620517 -0.348131
#  9  0.822611 -0.400705  0.530290 -0.461586]

# %%
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0  1.175015  1.322469 -1.692536  0.357526
# 1 -1.021023  1.781037  1.193684 -1.463627
# 2 -0.568609 -0.281539  1.014631  0.197154
# 3  2.453645 -0.004983  1.176666 -0.755122
# 4 -2.017929 -0.057934 -0.848184 -0.381368
# 5 -1.542693 -0.805007  0.919762 -0.098643
# 6 -1.217098 -1.100795 -0.160036 -1.177222
# 7 -0.411526  0.736221  0.586045 -0.099311
# 8  0.576997 -1.237087  1.620517 -0.348131
# 9  0.822611 -0.400705  0.530290 -0.461586

# %%
left = pd.DataFrame({"key": ["foo", "foo"], "lval": [1, 2]})

right = pd.DataFrame({"key": ["foo", "foo"], "rval": [4, 5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left,right)
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
df = pd.DataFrame(
    {
        "A": ["one", "one", "two", "three"] * 3,
        "B": ["A", "B", "C"] * 4,
        "C": ["foo", "foo", "foo", "bar", "bar", "bar"] * 2,
        "D": np.random.randn(12),
        "E": np.random.randn(12),
    }
)

# %%
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo  2.079701 -0.374362
# 1     one  B  foo  1.291370  0.072846
# 2     two  C  foo  0.072271 -1.010379
# 3   three  A  bar -0.291280  0.574107
# 4     one  B  bar  0.234264  0.372180
# 5     one  C  bar -0.643433  1.285936
# 6     two  A  foo  2.285506  0.112585
# 7   three  B  foo  0.999538 -0.571104
# 8     one  C  foo  0.460203 -1.311442
# 9     one  A  bar  0.320219  0.030905
# 10    two  B  bar -1.128380  1.369386
# 11  three  C  bar -1.670194  1.874838

# %%
pd.pivot_table(df, values="D", index=["A", "B"], columns=["C"])
# Out:
# C             bar       foo
# A     B
# one   A  0.320219  2.079701
#       B  0.234264  1.291370
#       C -0.643433  0.460203
# three A -0.291280       NaN
#       B       NaN  0.999538
#       C -1.670194       NaN
# two   A       NaN  2.285506
#       B -1.128380       NaN
#       C       NaN  0.072271

# %%
rng = pd.date_range("1/1/2012", periods=100, freq="S")

ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)

ts.resample("5Min").sum()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4912\324598162.py:1: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   rng = pd.date_range("1/1/2012", periods=100, freq="S")
# 2012-01-01    21571
# Freq: 5min, dtype: int32

# %%
ts_utc = ts.tz_localize("UTC")

# %%
ts_utc
# Out:
# 2012-01-01 00:00:00+00:00    212
# 2012-01-01 00:00:01+00:00    222
# 2012-01-01 00:00:02+00:00    485
# 2012-01-01 00:00:03+00:00    110
# 2012-01-01 00:00:04+00:00     96
#                             ...
# 2012-01-01 00:01:35+00:00    285
# 2012-01-01 00:01:36+00:00    149
# 2012-01-01 00:01:37+00:00    279
# 2012-01-01 00:01:38+00:00    372
# 2012-01-01 00:01:39+00:00     69
# Freq: s, Length: 100, dtype: int32

# %%
ts_utc.tz_convert("US/Eastern")
# Out:
# 2011-12-31 19:00:00-05:00    212
# 2011-12-31 19:00:01-05:00    222
# 2011-12-31 19:00:02-05:00    485
# 2011-12-31 19:00:03-05:00    110
# 2011-12-31 19:00:04-05:00     96
#                             ...
# 2011-12-31 19:01:35-05:00    285
# 2011-12-31 19:01:36-05:00    149
# 2011-12-31 19:01:37-05:00    279
# 2011-12-31 19:01:38-05:00    372
# 2011-12-31 19:01:39-05:00     69
# Freq: s, Length: 100, dtype: int32

# %%
rng
# Out:
# DatetimeIndex(['2012-01-01 00:00:00', '2012-01-01 00:00:01',
#                '2012-01-01 00:00:02', '2012-01-01 00:00:03',
#                '2012-01-01 00:00:04', '2012-01-01 00:00:05',
#                '2012-01-01 00:00:06', '2012-01-01 00:00:07',
#                '2012-01-01 00:00:08', '2012-01-01 00:00:09',
#                '2012-01-01 00:00:10', '2012-01-01 00:00:11',
#                '2012-01-01 00:00:12', '2012-01-01 00:00:13',
#                '2012-01-01 00:00:14', '2012-01-01 00:00:15',
#                '2012-01-01 00:00:16', '2012-01-01 00:00:17',
#                '2012-01-01 00:00:18', '2012-01-01 00:00:19',
#                '2012-01-01 00:00:20', '2012-01-01 00:00:21',
#                '2012-01-01 00:00:22', '2012-01-01 00:00:23',
#                '2012-01-01 00:00:24', '2012-01-01 00:00:25',
#                '2012-01-01 00:00:26', '2012-01-01 00:00:27',
#                '2012-01-01 00:00:28', '2012-01-01 00:00:29',
# ...

# %%
DatetimeIndex(['2012-03-06', '2012-03-07', '2012-03-08', '2012-03-09',
               '2012-03-10'],
              dtype='datetime64[ns]', freq='D')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 DatetimeIndex(['2012-03-06', '2012-03-07', '2012-03-08', '2012-03-09',
#       2                '2012-03-10'],
#       3               dtype='datetime64[ns]', freq='D')
#
# NameError: name 'DatetimeIndex' is not defined

# %%
rng + pd.offsets.BusinessDay(5)

# %%
DatetimeIndex(['2012-03-13', '2012-03-14', '2012-03-15', '2012-03-16',
               '2012-03-16'],
              dtype='datetime64[ns]', freq=None)

# %%
df["grade"] = df["raw_grade"].astype("category")

df["grade"]

# %%
df.iloc[3:5, 0:2]
df

# %%
import matplotlib.pyplot as plt

plt.close("all")

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))

# %%
ts = ts.cumsum()

# %%
ts.plot();

# %%
df = pd.DataFrame(
np.random.randn(1000, 4), index=ts.index, columns=["A", "B", "C", "D"]


df = df.cumsum()
 df.plot();
 plt.legend(loc='best');
